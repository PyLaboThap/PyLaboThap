# %% [markdown]
# # New Notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run component/heat_exchanger/pinch_cst/example.py
# Out:
# Error: Incorrect fluid name: Oil
# Inlet evaporator
# Fluid: R245fa
# Mass flow rate: 0.0638[kg/s]
# Volume flow rate: None[m^3/h]
# Temperature: None[K]
# Pressure: None[Pa]
# Spec. enthalpy: 249154[J/kg]
# Spec. entropy: None[J/kg/K]
# Mass density: None[kg/m^3]
# Quality: None[-]
# None
# Error: Incorrect fluid name: None
# Outelt evaporator
# Fluid: R245fa
# Mass flow rate: 0.0638[kg/s]
# Volume flow rate: 1.33657568483704[m^3/h]
# Temperature: 414.7720695530616[K]
# Pressure: 2664052.983186789[Pa]
# Spec. enthalpy: 499156.8886323208[J/kg]
# Spec. entropy: 1823.8593998240135[J/kg/K]
# Mass density: 171.84212058144942[kg/m^3]
# Quality: -1.0[-]
# None

# %%
# %run machine/cycle/ORC.py
# Out:
# Linked Pump.m-ex to Evaporator.m-su_wf
# Linked Evaporator.m-ex_wf to Expander.m-su
# Linked Expander.m-ex to Condenser.m-su_wf
# Linked Condenser.m-ex_wf to Pump.m-su
# 148581.0682882066 P_cd_guess
# 1005936.7328231519 P_ev_guess
# Iteration 0: Solving the cycle.
# 1005936.7328231519 evaporator.model.ex_wf.p
# 148581.0682882066 condenser.model.ex_wf.p
# 1005936.7328231519 pump.model.ex.p
# 148581.0682882066 pump.model.su.p
# 475938.11735461047 h_ex_ev
# 226428.6061786901 h_ex_cd
# 148581.0682882066 pump.model.su.p
# 1005936.7328231519 pump.model.ex.p
# Solving Pump
# Inlet pump
# Fluid: R245fa
# Mass flow rate: 0.06[kg/s]
# Volume flow rate: 0.15976353494362547[m^3/h]
# Temperature: 293.15000000002055[K]
# Pressure: 148581.0682882066[Pa]
# Spec. enthalpy: 226428.6061786901[J/kg]
# Spec. entropy: 1093.3442863494852[J/kg/K]
# Mass density: 1351.998126958184[kg/m^3]
# Quality: -1.0[-]
# None
# P_ex_pp =  1005936.7328231519
# Outlet pump
# Fluid: R245fa
# Mass flow rate: 0.06[kg/s]
# ...

# %%
PropsSI('H', 'P', 2836995.4768591095, 'T', 418.15000000000003, 'R245fa')
# Out:
# 499865.3555553735

# %%
# %run component/volumetric_machine/expander/constant_isentropic_efficiency/example.py
# Out:
# === Expander Setup ===
# Connectors:
#   - su: fluid=None, T=None, p=None, m_dot=None
#   - ex: fluid=None, T=None, p=None, m_dot=None
#
# Inputs:
#   - su_p: Not set
#   - su_T: Not set
#   - ex_p: Not set
#   - su_fluid: Not set
#
# Parameters:
#   - eta_is: Not set
# ...
# === Expander Setup ===
# Connectors:
#   - su: fluid=R134a, T=374.18, p=955214.9, m_dot=None
#   - ex: fluid=R1233ZDE, T=None, p=293940.1, m_dot=None
#
# Inputs:
#   - su_p: 955214.9
#   - su_T: 374.18
#   - ex_p: 293940.1
#   - su_fluid: R134a
#
# Parameters:
#   - eta_is: 0.8
# ...
# === Expander Results ===
#   - h_ex: 444972.0756565634 [J/kg]
#   - T_ex: 323.22098271389814 [K]
#   - w_exp: 39813.66483686358 [J/kg]
# ...
