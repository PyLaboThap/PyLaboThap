# %%
# %run library/machine/closed_machine/RC.py
# Out:
# Linked Pump.m-ex to Evaporator.m-su_C
# Linked Evaporator.m-ex_C to Expander.m-su
# Linked Expander.m-ex to Condenser.m-su_H
# Linked Condenser.m-ex_H to Pump.m-su
# P_ev_guess 1930376.675583079
# P_cd_guess 178079.0765039041
# Residuals variables: ['Evaporator:ex_C-h', 'Condenser:ex_H-h']
# Iteration 0: Solving the cycle.
# Residual Evaporator:ex_C-h: None
# Residual Condenser:ex_H-h: 232991.24664278625
# Solving Pump
# === Pump Results ===
#   - h_ex: 233775.56985350722 [J/kg]
#   - T_ex: 298.3488559733991 [K]
#   - w_pp: 784.3232107209624 [J/kg]
#   - W_dot_pp: 47.05939264325774 [W]
# ...
# Solving Evaporator
# === Heat Exchanger Results ===
# Q: 15965.387142111975
# P_sat: 2836995.4768591095
# ...
# Solving Expander
# === Expander Results ===
#   - h_ex: 435279.44131021114 [J/kg]
#   - T_ex: 311.09536117372704 [K]
#   - w_exp: 64585.914245162334 [J/kg]
#   - W_dot_exp: 3875.15485470974 [W]
# ...
# Solving Condenser
# === Heat Exchanger Results ===
# Q: 10909.671013976289
# ...

# %%
pip install CoolProp
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Le chemin d'acc�s sp�cifi� est introuvable.
